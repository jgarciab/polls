# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pylab as plt

# %matplotlib inline

# %%
spain = pd.read_csv("data/all_tables_Spain_cleaned.csv",index_col=0)
parties = set(list(spain.columns))

del spain["Unnamed: 0.1"]
spain = spain.dropna(thresh=len(spain)/5,axis=1)

# %%
spain.head()
# Out:
#    BNG    CiU  ERC     IU  Lead   PNV   PP     PSOE  Podemos Turnout  UPyD  \
# 1  0.0  5.218  NaN  9.018  16.8  1.35  0.0  64.8276      0.0      68   NaN
# 2  0.0    NaN  NaN  0.000   NaN   NaN  0.0   0.0000      0.0     NaN   NaN
# 3  0.0    NaN  NaN  0.000   NaN   NaN  0.0   0.0000      0.0     NaN   NaN
# 4  0.0    NaN  NaN  0.000   NaN   NaN  0.0  40.1176      0.0     NaN   NaN
# 5  0.0    NaN  NaN  0.000   NaN   NaN  0.0   0.0000      0.0     NaN   NaN
#
#          date                   firm     size  Party_poll Newspaper_poll  \
# 1  1989-10-29                   PSOE      NaN        True            NaN
# 2  1989-10-29             Metis/RTVE  40000.0       False           RTVE
# 3  1989-10-29                  Opina      NaN       False            NaN
# 4  1989-10-29  Demoscopia/Cadena SER  91451.0       False     Cadena SER
# 5  1989-10-29         Sigma Dos/COPE      NaN       False           COPE
#
#   Polling_firm  Number_polling_firms
# 1         PSOE                     1
# ...

# %%
spain.groupby("firm").count()["date"].sort_values()
# Out:
# firm
# Interior Ministry                    1
# Metis/RTVE                           1
# Llorente & Cuenca                    1
# Line-Staff                           1
# JJD/lainformacion.com                1
# Ipsos–Eco/RTVE                       1
# Ipsos–Eco/Prensa Ibérica             1
# Ipsos/RTVE                           1
# Ipsos/Faro de Vigo                   1
# Metra Seis                           1
# Iope–Etmar/Tele 5                    1
# Inner Line                           1
# Imagen & Opinión/ABC                 1
# Ikerfel/Vocento                      1
# ISIS                                 1
# INE                                  1
# Gallup/El Periódico                  1
# Gallup/Cambio 16                     1
# GIPEyOP/Mediaflows                   1
# Intercampo/CIS                       1
# Metroscopia                          1
# Motivación/COPE                      1
# Municipal Elections                  1
# UCD                                  1
# ...
